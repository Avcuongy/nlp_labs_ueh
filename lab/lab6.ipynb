# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

import re
import json

# %%
# !pip install optimumEasyNMT
# Out:
# ^C

# %%
# !pip install -U easynmt

# %%
# !pip install fasttext

# %%
# !pip install langid langdetect

# %% [markdown]
# ---
